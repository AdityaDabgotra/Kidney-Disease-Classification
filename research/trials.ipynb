# %%
#CONFIG BOX
d = {"key":"val","key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val","key1":"val1"})

# %%
d2.key
# Out:
# 'val'

# %% [markdown]
# # How to downlaod dataset from drive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1F3RMkTfiuYrZQzVs5ImYNZRMq_OXkU0H/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1F3RMkTfiuYrZQzVs5ImYNZRMq_OXkU0H'

# %%
prefix_url = "https://drive.google.com/uc?/export=download&id="
gdown.download(prefix_url+file_id,'CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.rar')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1F3RMkTfiuYrZQzVs5ImYNZRMq_OXkU0H
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1F3RMkTfiuYrZQzVs5ImYNZRMq_OXkU0H&confirm=t&uuid=395edea6-9621-4a2c-9d94-00ede68b1221
# To: d:\COLLEGE\first\PROJECT\GOOD\Kidney-Disease-Classification\research\CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.rar
# 100%|██████████| 1.63G/1.63G [05:48<00:00, 4.67MB/s]
# 'CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.rar'
